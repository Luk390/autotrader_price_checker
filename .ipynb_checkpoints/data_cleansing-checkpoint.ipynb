# %%
import pandas as pd
import missingno as msno
import numpy as np

# %%
raw_data = pd.read_csv('df.csv', header=0)

# %%
raw_data.head()
# Out:
#    body_type  co2Emissions condition  \
# 0  Hatchback         101.0      Used
# 1      Coupe         163.0      Used
# 2  Hatchback         105.0      Used
# 3        SUV         161.0      Used
# 4  Hatchback          93.0      Used
#
#                                          description  doors  emailAddress  \
# 0  FOR SALE WE HAVE THIS LOVELY FORD FIESTA 1.1 T...    5.0           NaN
# 1  BUY NOW PAY LATER, 1st payment deferred 3 mont...    2.0           NaN
# 2  We are selling our fav car in the family, Clio...    5.0           NaN
# 3  BUY NOW PAY LATER, 1st payment deferred 3 mont...    5.0           NaN
# 4  * PLEASE READ * IMOLA OF BRISTOL HAVE HUGE PLE...    5.0           NaN
#
#   engine_size fuel_type isTradeSeller        make  ...     model    price  \
# 0        1.1L    Petrol          True        Ford  ...    Fiesta   9300.0
# 1        3.0L    Petrol          True         BMW  ...  2 Series  21745.0
# 2        0.9L    Petrol         False     Renault  ...      Clio   8455.0
# 3        2.0L    Petrol          True  Alfa Romeo  ...   Stelvio  27990.0
# 4        1.0L    Petrol          True     Citroen  ...        C1   7500.0
#
#                                         raw_response  seats status_code  \
# 0  {"vehicle":{"make":"Ford","model":"Fiesta","tr...    5.0         200
# 1  {"vehicle":{"make":"BMW","model":"2 Series","t...    4.0         200
# 2  {"vehicle":{"make":"Renault","model":"Clio","t...    5.0         200
# 3  {"vehicle":{"make":"Alfa Romeo","model":"Stelv...    5.0         200
# 4  {"vehicle":{"make":"Citroen","model":"C1","tri...    4.0         200
#
#      tax  townAndDistance  transmission             trim  \
# 0  150.0          Bristol        Manual            Zetec
# 1  150.0          Bristol     Automatic          M Sport
# 2  150.0          Bristol        Manual  Dynamique S Nav
# 3  150.0          Bristol     Automatic      Tb Speciale
# 4  150.0          Bristol        Manual       Urban Ride
#
#                                                  url
# 0  https://www.autotrader.co.uk/classified/advert...
# 1  https://www.autotrader.co.uk/classified/advert...
# 2  https://www.autotrader.co.uk/classified/advert...
# 3  https://www.autotrader.co.uk/classified/advert...
# 4  https://www.autotrader.co.uk/classified/advert...
#
# [5 rows x 22 columns]

# %%
df = raw_data.drop(['description', 'emailAddress', 'raw_response', 'status_code', 'tax'], axis=1)
df.head()
# Out:
#    body_type  co2Emissions condition  doors engine_size fuel_type  \
# 0  Hatchback         101.0      Used    5.0        1.1L    Petrol
# 1      Coupe         163.0      Used    2.0        3.0L    Petrol
# 2  Hatchback         105.0      Used    5.0        0.9L    Petrol
# 3        SUV         161.0      Used    5.0        2.0L    Petrol
# 4  Hatchback          93.0      Used    5.0        1.0L    Petrol
#
#   isTradeSeller        make  manufactured_year  mileage     model    price  \
# 0          True        Ford             2018.0  21400.0    Fiesta   9300.0
# 1          True         BMW             2018.0  28261.0  2 Series  21745.0
# 2         False     Renault             2018.0  19981.0      Clio   8455.0
# 3          True  Alfa Romeo             2018.0  11204.0   Stelvio  27990.0
# 4          True     Citroen             2018.0  13450.0        C1   7500.0
#
#    seats townAndDistance transmission             trim  \
# 0    5.0         Bristol       Manual            Zetec
# 1    4.0         Bristol    Automatic          M Sport
# 2    5.0         Bristol       Manual  Dynamique S Nav
# 3    5.0         Bristol    Automatic      Tb Speciale
# 4    4.0         Bristol       Manual       Urban Ride
#
#                                                  url
# 0  https://www.autotrader.co.uk/classified/advert...
# 1  https://www.autotrader.co.uk/classified/advert...
# 2  https://www.autotrader.co.uk/classified/advert...
# 3  https://www.autotrader.co.uk/classified/advert...
# 4  https://www.autotrader.co.uk/classified/advert...

# %%
#check categorical variables - body_type, condition, fuel_type, isTradeSeller, make, model, townAndDistance, transmission, trim
for column in ['body_type', 'condition', 'fuel_type', 'isTradeSeller', 'make', 'model', 'townAndDistance', 'transmission', 'trim']:
    print(df[column].value_counts().sort_index())
    print('\n')
# Out:
# Convertible     137
# Coupe           286
# Estate          255
# Hatchback      3176
# Limousine         3
# MPV             115
# Pickup            1
# SUV            1547
# Saloon          287
# Name: body_type, dtype: int64
#
#
# Nearly New    1710
# Used          4118
# Name: condition, dtype: int64
#
#
# Petrol    5828
# Name: fuel_type, dtype: int64
#
#
# False     257
# True     5571
# Name: isTradeSeller, dtype: int64
#
#
# Abarth             19
# Alfa Romeo         13
# Aston Martin       14
# Audi              333
# BMW               293
# Bentley            29
# CUPRA               2
# Citroen            86
# DS AUTOMOBILES     10
# Dacia              52
# Ferrari            12
# Fiat               68
# Ford              831
# Honda             125
# Hyundai           219
# Jaguar             55
# Jeep               16
# Kia               225
# Lamborghini        15
# Land Rover         34
# Lexus               1
# MG                 35
# MINI              164
# Maserati           46
# Mazda             112
# McLaren            10
# Mercedes-Benz     298
# Mitsubishi         47
# Nissan            349
# Peugeot           227
# Porsche            70
# Renault           140
# Rolls-Royce       129
# SEAT              152
# SKODA             138
# Smart               9
# SsangYong           9
# Subaru              2
# Suzuki             60
# Toyota            345
# Vauxhall          491
# Volkswagen        403
# Volvo             140
# Name: make, dtype: int64
#
#
# 1 Series                   60
# 108                        49
# 124 Spider                  4
# 2 Series                   32
# 2 Series Active Tourer     14
# 2 Series Gran Coupe         1
# 2 Series Gran Tourer       15
# 2008                       37
# 208                        60
# 3 Series                   42
# 3 Series Gran Turismo       3
# 3008                       32
# 308                        28
# 308 SW                      5
# 320                         1
# 370 Z                       4
# 4 Series                   19
# 4 Series Gran Coupe        13
# 488                         7
# 5 Series                   19
# 500                        35
# 5008                        4
# 500C                        1
# 500X                        7
# 508                         7
# 508 SW                      4
# 570GT                       2
# 570S                        1
# 595                        16
# 595C                        1
#                          ...
# Venga                       5
# Vitara                     24
# Viva                       27
# WRX STI                     1
# Wraith                     23
# Wrangler                    6
# X-Trail                     2
# X1                         19
# X2                         18
# X3                          6
# X3 M                        1
# X4                          2
# X5                          1
# X6                          1
# XC40                       19
# XC60                       17
# XC90                        4
# XCeed                       8
# XE                         13
# XF                         10
# Yaris                     192
# Z4                          4
# Zafira Tourer               5
# forfour                     4
# fortwo                      5
# i10                        44
# i20                        21
# i30                        28
# ix20                        4
# up!                        34
# Name: model, Length: 307, dtype: int64
#
#
# Acton                  54
# Altrincham             51
# Ashton-Under-Lyne      38
# Balham                  1
# Barking                 2
# Barnet                  7
# Bath                   82
# Batley                 21
# Battersea              12
# Beckenham              14
# Bilston                59
# Birmingham            620
# Bloomsbury              1
# Bolton                 78
# Bow                     3
# Bradford              184
# Brentford              40
# Brierley Hill          17
# Bristol              1073
# Brixton                 3
# Bromley                29
# Bury                  140
# Camden Town            32
# Castleford              3
# Catford                 2
# Charlton                2
# Cheadle                 7
# Chingford               7
# Chippenham              1
# Chiswick                8
#                      ...
# Swindon                 4
# Sydenham                1
# Thamesmead              2
# The Hyde               28
# Thornton Heath          3
# Tipton                  6
# Tooting                 8
# Tottenham               8
# Twickenham              1
# Upper Edmonton          1
# Victoria Docks          4
# Wakefield             203
# Walsall                53
# Walthamstow             7
# Wandsworth              2
# Wednesbury             16
# Welling                 2
# Wembley                23
# West Brompton           8
# West Bromwich          50
# Westminster             1
# Wetherby                1
# Whetstone              13
# Willenhall             37
# Willesden             194
# Wilmslow                2
# Wimbledon              10
# Winchmore Hill          2
# Woodford Green          4
# Woolwich                2
# Name: townAndDistance, Length: 150, dtype: int64
#
#
# Automatic    2368
# Manual       3456
# Name: transmission, dtype: int64
#
#
# 1                                                     7
# 1.0 Tsi 95 Fr [Ez] 5Dr                                1
# 1.5                                                   1
# 1.5 Manual                                            1
# 1.5 Tsi Evo Fr Sport [Ez] 5Dr                         1
# 1.6 T-gdi 177ps N Line Dct                            1
# 120th Anniversary                                     1
# 2                                                    11
# 2.0 T5 [250] R Design 5Dr Awd Geartronic              1
# 3                                                    10
# 35 TFSI S Line Contrast Ed 5dr S Tronic [Tech Pk]     1
# 4                                                     4
# 4S                                                    1
# 500 My17 1.2 69hp Lounge                              1
# 595 Competizione                                      2
# 595 Competizione Mta                                  2
# 595 Turismo                                           1
# 70th                                                  3
# 991 Carrera 4 GTS                                     2
# 991 Carrera GTS                                       1
# 991 GT3 RS                                            1
# 992 Carrera                                           1
# 992 Carrera 4                                         3
# 992 Carrera S                                         2
# AMG                                                  22
# AMG Edition                                           1
# AMG Line                                             39
# AMG Line Edition                                      1
# AMG Line Night Edition                                1
# AMG Night Edition                                     4
#                                                      ..
# Turismo 70th                                          1
# Twinair                                               1
# Twinair Cross                                         2
# Twinair Speciale                                      1
# Type R GT                                             3
# Type UK                                               1
# Ultimate                                              2
# Ultra Prestige                                        1
# Urban Edition                                        14
# Urban Ride                                            6
# V6 Sahara Unlimited                                   1
# VXR                                                   1
# Veloce                                                2
# Venture Edition                                       1
# Vignale                                               2
# Waze Edition                                          1
# X-Line S                                              1
# XCELLENCE                                             2
# XCELLENCE Lux                                         6
# Y20                                                   1
# Zetec                                                26
# Zetec Edition                                         2
# up! GTI                                               5
# up! beats                                             2
# x-play                                                9
# x-plore                                               3
# x-press                                               4
# x-style                                               1
# x-trend                                              13
# xLine                                                 6
# Name: trim, Length: 315, dtype: int64

# %%
#Drop Pickup and Limosine due to low values
df.drop(df[(df['body_type'] == 'Limousine') | (df['body_type'] == 'Pickup')].index, inplace=True)


#Drop CUPRA, Lexus and Subarus due to low sample numbers
df.drop(df[(df['make'] == 'Subaru') | (df['make'] == 'CUPRA') | (df['make'] == 'Lexus')].index, inplace=True)

#After confirming all the cars are indeed petrol, this column can be dropped
df.drop(['fuel_type'], axis=1, inplace=True)

#The data was scraped as 10 miles from the center of Bristol, London, Birmingham, Leeds and Manchester. 
#So will assign these values to a new column based on the postcode used in url

location_dict = {'bs11aa': 'Bristol', 
                 'wc2n5du': 'London', 
                 'b11bb': 'Birmingham', 
                 'ls11az': 'Leeds', 
                 'm11ag': 'Manchester'}
def location_url(string):
    for key in location_dict.keys():
        if key in string:
            return location_dict[key]

df['location'] = df.url.map(location_url)

#Drop url and townAndDistance columns as no longer needed
df.drop(['url', 'townAndDistance'], axis=1, inplace=True)

#Trim L of engine_size
df['engine_size'] = df['engine_size'].apply(lambda x: str(x)[:-1])

#Replace string 'na' with np.Nan
df['engine_size'] = df['engine_size'].apply(lambda x: np.NaN if x == 'na' else x)

#Drop column trim due to over 60% values missing.
#This is not so much of a problem because there were over 300 unique trim options, so would have drastically upped the 
#number dummy variables needed
df.drop(['trim'], axis=1, inplace=True)

#Fix a specific instance where one record's engine size was 1000 times what is should have been
df.engine_size = df.apply(lambda x: 0.9 if x.engine_size == '875.0' else x.engine_size, axis=1)

# %%
msno.bar(df)

# %%
#I decided that I due to the relatively low number of records which have missing values. 
#I would drop a row if there was any missing values. This drops the total records from 5842 to 5525
df = df.dropna()

# %%
msno.bar(df)

# %%
df.dtypes
# Out:
# body_type             object
# co2Emissions         float64
# condition             object
# doors                float64
# engine_size           object
# isTradeSeller         object
# make                  object
# manufactured_year    float64
# mileage              float64
# model                 object
# price                float64
# seats                float64
# transmission          object
# location              object
# dtype: object

# %%
for column in ['body_type', 'condition', 'isTradeSeller', 'make', 'model', 'transmission', 'location']:
    df[column] = df[column].astype('category')
    
for column in ['co2Emissions', 'doors', 'manufactured_year', 'mileage', 'seats']:
    df[column] = df[column].astype('int64', copy=False)

df.engine_size = df.engine_size.astype('float64')

# %%
df.dtypes
# Out:
# body_type            category
# co2Emissions            int64
# condition            category
# doors                   int64
# engine_size           float64
# isTradeSeller        category
# make                 category
# manufactured_year       int64
# mileage                 int64
# model                category
# price                 float64
# seats                   int64
# transmission         category
# location             category
# dtype: object

# %%
df.to_csv('data.csv')

# %% [markdown]
# All data has been cleaned and saved in data.csv.
